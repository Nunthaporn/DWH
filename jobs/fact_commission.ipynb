# %%
import pandas as pd
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine
import numpy as np

# โหลดตัวแปรจาก .env
load_dotenv()

# ดึงค่าจาก environment
user = os.getenv('DB_USER')
password = os.getenv('DB_PASSWORD')
host = os.getenv('DB_HOST')
port = os.getenv('DB_PORT')  
database = 'fininsurance'

# สร้าง engine สำหรับเชื่อมต่อฐานข้อมูล
engine = create_engine(f'mariadb+mariadbconnector://{user}:{password}@{host}:{port}/{database}')

# SQL query
query = """
SELECT quo_num,id_cus,no_car ,current_campaign 
FROM fin_system_select_plan WHERE datestart >= '2025-05-01' AND datestart < '2025-07-01' 
"""


# โหลดข้อมูลจากฐานข้อมูล
df_select_plan = pd.read_sql(query, engine)

# แปลงให้ pandas เข้าใจได้แน่นอน
df_select_plan
# Out:
#              quo_num        id_cus no_car current_campaign
# 0       FQ2505-02001   FNG21-19117    110             None
# 1       FN2505-00101  FNG23-105321   None             None
# 2       FQ2505-02002   FNG21-39576    320
# 3       FV2505-02001   FNG21-34561   None             None
# 4       FQ2505-02003   FNG21-26630    110             None
# ...              ...           ...    ...              ...
# 127805  FQ2506-26312    FNG20-8942   110E
# 127806  FQ2506-26313  FNG25-135365    110             None
# 127807  FQ2506-26314   FNG21-16203    610             None
# 127808  FQ2506-26315  FNG23-083242    110             None
# 127809  FN2506-03630  FNG23-102679   None             None
#
# [127810 rows x 4 columns]

# %%
import pandas as pd
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine

load_dotenv() 

user = os.getenv('DB_USER')
password = os.getenv('DB_PASSWORD')
host = os.getenv('DB_HOST')
port = os.getenv('DB_PORT')  
database = 'fininsurance_task'

engine = create_engine(f'mariadb+mariadbconnector://{user}:{password}@{host}:{port}/{database}')

query = """
SELECT quo_num,numpay,order_number
FROM   fin_order   WHERE datekey >= '2025-05-01' AND datekey < '2025-07-01'
"""

df_fin_order = pd.read_sql(query, engine)
df_fin_order
# Out:
#                quo_num numpay   order_number
# 0         FV2505-02009      1  VIN2505-00001
# 1         FV2505-02011      1  VIN2505-00002
# 2         FV2505-02012      1  VIN2505-00003
# 3         FV2505-02013      1  VIN2505-00004
# 4         FV2505-02014      1  VIN2505-00005
# ...                ...    ...            ...
# 91584  FL2506-02041-01      1  FAL2506-00029
# 91585  FL2506-02042-01      1  LIN2506-00057
# 91586  FL2506-02043-01      1  LIN2506-00058
# 91587     FQ2506-26304      1  FAM2506-04637
# 91588  FL2506-02044-01      1  LIN2506-00059
#
# [91589 rows x 3 columns]

# %%
import pandas as pd
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine
import numpy as np

# โหลดตัวแปรจาก .env
load_dotenv()

# ดึงค่าจาก environment
user = os.getenv('DB_USER')
password = os.getenv('DB_PASSWORD')
host = os.getenv('DB_HOST')
port = os.getenv('DB_PORT')  
database = 'fininsurance'

# สร้าง engine สำหรับเชื่อมต่อฐานข้อมูล
engine = create_engine(f'mariadb+mariadbconnector://{user}:{password}@{host}:{port}/{database}')

# SQL query
query = """
SELECT quo_num,show_com_total,show_com_prb,show_com_ins,discom,show_price_com_count,show_com_addon,condition_install,percent_install,chanel_main
FROM fin_system_pay WHERE datestart >= '2025-05-01' AND datestart < '2025-07-01'
"""


# โหลดข้อมูลจากฐานข้อมูล
df_system_pay = pd.read_sql(query, engine)

df_system_pay
# Out:
#              quo_num show_com_total show_com_prb show_com_ins  discom  \
# 0       FN2504-02806        4118.19         None    4297.0365       0
# 1       FQ2505-02002        2219.82            0      2378.76       0
# 2       FQ2504-24451         389.77            0       452.39       0
# 3       FV2505-02001           None         None         None    None
# 4       FV2505-02002         228.22       228.22                    0
# ...              ...            ...          ...          ...     ...
# 104720  FQ2506-26307          74.00          120                    0
# 104721  FQ2506-26308         265.29            0      1396.26  279.25
# 104722  FN2506-03629          43.29         None        45.57       0
# 104723  FN2506-03305        3906.11         None      4153.80       0
# 104724  FQ2506-26312                           0      1341.34
#
#        show_price_com_count show_com_addon condition_install percent_install  \
# 0                   4118.19           None                                 0
# 1                   2219.82              0                              None
# 2                    389.77              0                              None
# 3                      None           None              None            None
# 4                         0           None              None            None
# ...                     ...            ...               ...             ...
# 104720                74.00              0                                 0
# 104721               265.29              0            000002              10
# 104722                43.29           None                                 0
# 104723              3906.11           None                                 0
# 104724                    0              0            000002               8
#
#           chanel_main
# 0             โอนเงิน
# 1             โอนเงิน
# 2             โอนเงิน
# 3                None
# 4             โอนเงิน
# ...               ...
# 104720        โอนเงิน
# 104721        ผ่อนโอน
# 104722        โอนเงิน
# 104723  ตัดบัตรเครดิต
# 104724       ผ่อนชำระ
#
# [104725 rows x 10 columns]

# %%
import pandas as pd
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine
import numpy as np

# โหลดตัวแปรจาก .env
load_dotenv()

# ดึงค่าจาก environment
user = os.getenv('DB_USER')
password = os.getenv('DB_PASSWORD')
host = os.getenv('DB_HOST')
port = os.getenv('DB_PORT')  
database = 'fininsurance'

# สร้าง engine สำหรับเชื่อมต่อฐานข้อมูล
engine = create_engine(f'mariadb+mariadbconnector://{user}:{password}@{host}:{port}/{database}')

# SQL query
query = """
SELECT quo_num,com_invite,com_rank
FROM fin_com_rank WHERE date_add >= '2025-05-01' AND date_add < '2025-07-01'
"""


# โหลดข้อมูลจากฐานข้อมูล
df_com_rank = pd.read_sql(query, engine)

# แปลงให้ pandas เข้าใจได้แน่นอน
df_com_rank
# Out:
#             quo_num com_invite com_rank
# 0      FN2504-02806          0   286.47
# 1      FN2504-02806          0   572.94
# 2      FV2505-02002          3        0
# 3      FV2505-02003          3        0
# 4      FV2505-02004          3        0
# ...             ...        ...      ...
# 88797  FQ2506-26308      111.7        0
# 88798  FQ2506-26308          0    55.85
# 88799  FN2506-03629       6.08        0
# 88800  FN2506-03629          0     3.04
# 88801  FN2506-03629          0     0.76
#
# [88802 rows x 3 columns]

# %%
import pandas as pd
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine
import numpy as np

# โหลดตัวแปรจาก .env
load_dotenv()

# ดึงค่าจาก environment
user = os.getenv('DB_USER')
password = os.getenv('DB_PASSWORD')
host = os.getenv('DB_HOST')
port = os.getenv('DB_PORT')  
database = 'fininsurance'

# สร้าง engine สำหรับเชื่อมต่อฐานข้อมูล
engine = create_engine(f'mariadb+mariadbconnector://{user}:{password}@{host}:{port}/{database}')

# SQL query
query = """
SELECT cuscode as id_cus,status_vip 
FROM wp_users where  cuscode not in ("FINTEST-01", "FIN-TestApp", "Admin-VIF", "adminmag_fin")

"""


# โหลดข้อมูลจากฐานข้อมูล
df_wp_users = pd.read_sql(query, engine)

# แปลงให้ pandas เข้าใจได้แน่นอน
df_wp_users
# Out:
#                           id_cus status_vip
# 0                    FIN19090009         no
# 1                        FINBANK         no
# 2       punyawat@dplusonline.net         no
# 3                      FIN19-jay         no
# 4                     FIN0000000         no
# ...                          ...        ...
# 140047              FNG25-138665         no
# 140048              FNG25-138666         no
# 140049              FNG25-138667         no
# 140050              FNG25-138668         no
# 140051              FNG25-138669         no
#
# [140052 rows x 2 columns]

# %%
import pandas as pd
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine
import numpy as np

# โหลดตัวแปรจาก .env
load_dotenv()

# ดึงค่าจาก environment
user = os.getenv('DB_USER')
password = os.getenv('DB_PASSWORD')
host = os.getenv('DB_HOST')
port = os.getenv('DB_PORT')  
database = 'fininsurance_task'

# สร้าง engine สำหรับเชื่อมต่อฐานข้อมูล
engine = create_engine(f'mariadb+mariadbconnector://{user}:{password}@{host}:{port}/{database}')

# SQL query
query = """
SELECT order_number, money_one ,money_ten 
FROM fin_finance
"""


# โหลดข้อมูลจากฐานข้อมูล
df_fin_finance = pd.read_sql(query, engine)

# แปลงให้ pandas เข้าใจได้แน่นอน
df_fin_finance
# Out:
#           order_number money_one money_ten
# 0        FIN1910-00002      3000      None
# 1        FIN1910-00003      3000      None
# 2        FIN1910-00004      3000      None
# 3        FIN1910-00005      3000      None
# 4        FIN1910-00006      3000      None
# ...                ...       ...       ...
# 1573290  FAL2506-00029   2594.74
# 1573291  LIN2506-00057  14817.39
# 1573292  LIN2506-00058  11400.00
# 1573293  FAM2506-04637  10457.05
# 1573294  LIN2506-00059  35310.39
#
# [1573295 rows x 3 columns]

# %%
df_merged = df_select_plan.copy()
df_merged = pd.merge(df_merged, df_fin_order, on='quo_num', how='left')
df_merged = pd.merge(df_merged, df_system_pay, on='quo_num', how='left')
df_merged = pd.merge(df_merged, df_com_rank, on='quo_num', how='left')
df_merged = pd.merge(df_merged, df_fin_finance, on='order_number', how='left')
df_merged = pd.merge(df_merged, df_wp_users, on='id_cus', how='left')
df_merged
# Out:
#              quo_num        id_cus no_car current_campaign numpay  \
# 0       FQ2505-02001   FNG21-19117    110             None    NaN
# 1       FN2505-00101  FNG23-105321   None             None    NaN
# 2       FQ2505-02002   FNG21-39576    320                     NaN
# 3       FV2505-02001   FNG21-34561   None             None    NaN
# 4       FQ2505-02003   FNG21-26630    110             None    NaN
# ...              ...           ...    ...              ...    ...
# 166799  FQ2506-26312    FNG20-8942   110E                     NaN
# 166800  FQ2506-26313  FNG25-135365    110             None    NaN
# 166801  FQ2506-26314   FNG21-16203    610             None    NaN
# 166802  FQ2506-26315  FNG23-083242    110             None    NaN
# 166803  FN2506-03630  FNG23-102679   None             None    NaN
#
#        order_number show_com_total show_com_prb show_com_ins discom  \
# 0               NaN            NaN          NaN          NaN    NaN
# 1               NaN            NaN          NaN          NaN    NaN
# 2               NaN        2219.82            0      2378.76      0
# 3               NaN           None         None         None   None
# 4               NaN            NaN          NaN          NaN    NaN
# ...             ...            ...          ...          ...    ...
# 166799          NaN                           0      1341.34
# 166800          NaN            NaN          NaN          NaN    NaN
# 166801          NaN            NaN          NaN          NaN    NaN
# 166802          NaN            NaN          NaN          NaN    NaN
# 166803          NaN            NaN          NaN          NaN    NaN
#
#        show_price_com_count show_com_addon condition_install percent_install  \
# 0                       NaN            NaN               NaN             NaN
# 1                       NaN            NaN               NaN             NaN
# 2                   2219.82              0                              None
# 3                      None           None              None            None
# 4                       NaN            NaN               NaN             NaN
# ...                     ...            ...               ...             ...
# 166799                    0              0            000002               8
# 166800                  NaN            NaN               NaN             NaN
# 166801                  NaN            NaN               NaN             NaN
# 166802                  NaN            NaN               NaN             NaN
# 166803                  NaN            NaN               NaN             NaN
#
#        chanel_main com_invite com_rank money_one money_ten status_vip
# 0              NaN        NaN      NaN      None      None         no
# 1              NaN        NaN      NaN      None      None         no
# 2          โอนเงิน        NaN      NaN      None      None         no
# 3             None        NaN      NaN      None      None    yes-old
# 4              NaN        NaN      NaN      None      None         no
# ...            ...        ...      ...       ...       ...        ...
# 166799    ผ่อนชำระ        NaN      NaN      None      None         no
# 166800         NaN        NaN      NaN      None      None         no
# 166801         NaN        NaN      NaN      None      None         no
# 166802         NaN        NaN      NaN      None      None         no
# 166803         NaN        NaN      NaN      None      None         no
#
# [166804 rows x 20 columns]

# %%
df_merged
# Out:
#             quo_num        id_cus no_car current_campaign numpay order_number  \
# 0      FQ2505-02001   FNG21-19117    110             None    NaN          NaN
# 1      FN2505-00101  FNG23-105321   None             None    NaN          NaN
# 2      FQ2505-02002   FNG21-39576    320                     NaN          NaN
# 3      FV2505-02001   FNG21-34561   None             None    NaN          NaN
# 4      FQ2505-02003   FNG21-26630    110             None    NaN          NaN
# ...             ...           ...    ...              ...    ...          ...
# 86244  FN2505-03998  FNG23-101153   None             None    NaN          NaN
# 86245  FQ2505-28009  FNG25-134164    320             None    NaN          NaN
# 86246  FQ2505-28010   FNG21-38733    110             None    NaN          NaN
# 86247  FQ2505-28011   FNG21-38733    110                     NaN          NaN
# 86248  FQ2505-28012    FNG20-1812    110             None    NaN          NaN
#
#       show_com_total show_com_prb show_com_ins discom show_price_com_count  \
# 0                NaN          NaN          NaN    NaN                  NaN
# 1                NaN          NaN          NaN    NaN                  NaN
# 2            2219.82            0      2378.76      0              2219.82
# 3               None         None         None   None                 None
# 4                NaN          NaN          NaN    NaN                  NaN
# ...              ...          ...          ...    ...                  ...
# 86244        2647.89         None    2829.3567      0              2647.89
# 86245        1155.39            0       1216.2      0              1155.39
# 86246            NaN          NaN          NaN    NaN                  NaN
# 86247            NaN          NaN          NaN    NaN                  NaN
# 86248            NaN          NaN          NaN    NaN                  NaN
#
#       show_com_addon condition_install percent_install chanel_main com_invite  \
# 0                NaN               NaN             NaN         NaN        NaN
# 1                NaN               NaN             NaN         NaN        NaN
# 2                  0                              None     โอนเงิน        NaN
# 3               None              None            None        None        NaN
# 4                NaN               NaN             NaN         NaN        NaN
# ...              ...               ...             ...         ...        ...
# 86244           None                                 0     โอนเงิน        NaN
# 86245              0                              None     โอนเงิน     187.11
# 86246            NaN               NaN             NaN         NaN        NaN
# 86247            NaN               NaN             NaN         NaN        NaN
# 86248            NaN               NaN             NaN         NaN        NaN
#
#       com_rank money_one money_ten status_vip
# 0          NaN      None      None         no
# 1          NaN      None      None         no
# 2          NaN      None      None         no
# 3          NaN      None      None    yes-old
# 4          NaN      None      None         no
# ...        ...       ...       ...        ...
# 86244      NaN      None      None         no
# 86245        0      None      None         no
# 86246      NaN      None      None         no
# 86247      NaN      None      None         no
# 86248      NaN      None      None    yes-old
#
# [86249 rows x 20 columns]

# %%
cols_to_numeric = ["numpay", "money_one", "money_ten"]

for col in cols_to_numeric:
    if col in df_merged.columns:
        df_merged[col] = pd.to_numeric(df_merged[col], errors="coerce")

# %%
def calculate_condi_com_status(row):
    if pd.notna(row["numpay"]) and row["numpay"] < 2:
        return "หารเท่าทุกงวด"
    
    if pd.notna(row["condition_install"]) and str(row["condition_install"]).startswith("0000"):
        return "หารเท่าทุกงวด"
    
    if (
        pd.notna(row["numpay"]) and row["numpay"] == 10 and
        pd.notna(row["money_one"]) and pd.notna(row["money_ten"]) and
        row["money_one"] == row["money_ten"]
    ):
        return "หารเท่าทุกงวด"
    
    if row.get("no_car") == "730":
        if pd.notna(row["condition_install"]) and str(row["condition_install"]).strip() != "":
            prefix = str(row["condition_install"])[:4]
            return f"งวดแรกจ่าย {prefix}"
        else:
            return "หารเท่าทุกงวด"

    return None

# %%
df_merged["condi_com_status"] = df_merged.apply(calculate_condi_com_status, axis=1)

# %%
import pandas as pd

# สร้างคอลัมน์ condi_com ตามเงื่อนไข
def calculate_condi_com(row):
    try:
        if (
            row["percent_install"] == 0
            or (
                row["percent_install"] == 0 and row["isGovernmentOfficer"] == 1 and pd.notna(row["chanel_main"]) and "ผ่อน" in row["chanel_main"]
            )
            or (
                row["current_campaign"] == "ผ่อนไม่หักคอม" and pd.notna(row["id_cus"]) and not row["id_cus"].startswith("FTR")
            )
        ):
            return "ไม่หักคอม"

        if pd.notna(row["id_cus"]) and row["id_cus"].startswith("FTR"):
            return "ปกติ"

        if pd.notna(row["chanel_main"]) and "ผ่อน" not in row["chanel_main"]:
            return "ปกติ"

        elif (
            pd.notna(row["datestart"])
            and row["datestart"] > pd.to_datetime("2024-07-17")
            and row["status_vip"] in ("yes", "yes-new")
            and row["numpay"] > 1
            and row["condition_install"] == "000003"
            and str(row["percent_install"]) in ["0.3", "0.5", "0.9", "1.2", "1.5", "1.8", "2.1", "2.4", "3", "1", "2", "2.5", "3.5", "4", "4.5", "5"]
        ):
            return "หักคอม 0.3,0.5"
        else:
            return "หักคอม"
    except Exception:
        return "หักคอม"

# สร้างคอลัมน์ใหม่
df_merged["condi_com"] = df_merged.apply(calculate_condi_com, axis=1)

# %%
import pandas as pd

# แปลงให้เป็นตัวเลขก่อน
df_merged["numpay"] = pd.to_numeric(df_merged["numpay"], errors="coerce")
df_merged["discom"] = pd.to_numeric(df_merged["discom"], errors="coerce")
df_merged["show_com_ins"] = pd.to_numeric(df_merged["show_com_ins"], errors="coerce")

# สร้างคอลัมน์ commission ตามเงื่อนไข
df_merged["commission"] = df_merged.apply(
    lambda row: row["discom"] if row["numpay"] > 1 else row["show_com_ins"],
    axis=1
)

# แสดงตัวอย่างผลลัพธ์
print(df_merged[["numpay", "discom", "show_com_ins", "commission"]].head())
# Out:
#    numpay  discom  show_com_ins  commission
# 0     NaN     NaN           NaN         NaN
# 1     NaN     NaN           NaN         NaN
# 2     NaN     0.0       2378.76     2378.76
# 3     NaN     NaN           NaN         NaN
# 4     NaN     NaN           NaN         NaN

# %%
for col in df_merged.columns:
    print(col)
##car_year
# Out:
# quo_num
# id_cus
# no_car
# current_campaign
# numpay
# order_number
# show_com_total
# show_com_prb
# show_com_ins
# discom
# show_price_com_count
# show_com_addon
# condition_install
# percent_install
# chanel_main
# com_invite
# com_rank
# money_one
# money_ten
# status_vip
# condi_com_status
# condi_com
# commission

# %%
rename_columns = {
    "quo_num": "quotation_num",
    "cuscode": "agent_id",
    "show_com_total": "total_commission",
    "show_com_prb": "ins_commission",
    "show_com_ins": "prb_commission",
    "discom": "after_tax_commission",
    "show_price_com_count": "paid_commission",
    "show_com_addon": "commission_addon",
    "com_invite": "com_invite",
    "com_rank": "com_rank",
    "condi_com_status": "condi_com_status",
    "condi_com": "condi_com",
    "commission": "commission",
}

df = df_merged.rename(columns=rename_columns)
df
# Out:
#        quotation_num        id_cus no_car current_campaign  numpay  \
# 0       FQ2505-02001   FNG21-19117    110             None     NaN
# 1       FN2505-00101  FNG23-105321   None             None     NaN
# 2       FQ2505-02002   FNG21-39576    320                      NaN
# 3       FV2505-02001   FNG21-34561   None             None     NaN
# 4       FQ2505-02003   FNG21-26630    110             None     NaN
# ...              ...           ...    ...              ...     ...
# 166799  FQ2506-26312    FNG20-8942   110E                      NaN
# 166800  FQ2506-26313  FNG25-135365    110             None     NaN
# 166801  FQ2506-26314   FNG21-16203    610             None     NaN
# 166802  FQ2506-26315  FNG23-083242    110             None     NaN
# 166803  FN2506-03630  FNG23-102679   None             None     NaN
#
#        order_number total_commission ins_commission  prb_commission  \
# 0               NaN              NaN            NaN             NaN
# 1               NaN              NaN            NaN             NaN
# 2               NaN          2219.82              0         2378.76
# 3               NaN             None           None             NaN
# 4               NaN              NaN            NaN             NaN
# ...             ...              ...            ...             ...
# 166799          NaN                               0         1341.34
# 166800          NaN              NaN            NaN             NaN
# 166801          NaN              NaN            NaN             NaN
# 166802          NaN              NaN            NaN             NaN
# 166803          NaN              NaN            NaN             NaN
#
#         after_tax_commission  ... percent_install chanel_main com_invite  \
# 0                        NaN  ...             NaN         NaN        NaN
# 1                        NaN  ...             NaN         NaN        NaN
# 2                        0.0  ...            None     โอนเงิน        NaN
# 3                        NaN  ...            None        None        NaN
# 4                        NaN  ...             NaN         NaN        NaN
# ...                      ...  ...             ...         ...        ...
# 166799                   NaN  ...               8    ผ่อนชำระ        NaN
# 166800                   NaN  ...             NaN         NaN        NaN
# 166801                   NaN  ...             NaN         NaN        NaN
# 166802                   NaN  ...             NaN         NaN        NaN
# 166803                   NaN  ...             NaN         NaN        NaN
#
#        com_rank money_one money_ten status_vip  condi_com_status  condi_com  \
# 0           NaN       NaN       NaN         no              None     หักคอม
# 1           NaN       NaN       NaN         no              None     หักคอม
# 2           NaN       NaN       NaN         no              None       ปกติ
# 3           NaN       NaN       NaN    yes-old              None     หักคอม
# 4           NaN       NaN       NaN         no              None     หักคอม
# ...         ...       ...       ...        ...               ...        ...
# 166799      NaN       NaN       NaN         no     หารเท่าทุกงวด     หักคอม
# 166800      NaN       NaN       NaN         no              None     หักคอม
# 166801      NaN       NaN       NaN         no              None     หักคอม
# 166802      NaN       NaN       NaN         no              None     หักคอม
# 166803      NaN       NaN       NaN         no              None     หักคอม
#
#        commission
# 0             NaN
# 1             NaN
# 2         2378.76
# 3             NaN
# 4             NaN
# ...           ...
# 166799    1341.34
# 166800        NaN
# 166801        NaN
# 166802        NaN
# 166803        NaN
#
# [166804 rows x 23 columns]

# %%
df_merged = df_merged.drop(columns=['numpay','current_campaign','status_vip','percent_install','chanel_main','no_car','condition_install','chanel_main','money_one','money_ten','order_number'])
df_merged
# Out:
#        quotation_num      agent_id  total_commission  ins_commission  \
# 0       FQ2506-04350  FNG23-107003           1290.30             0.0
# 1       FQ2505-04940  FNG23-104859            738.66             0.0
# 2       FQ2505-24128   FNG21-24169            814.99             0.0
# 3       FQ2505-14310  FNG22-064792           1026.71             0.0
# 4       FQ2505-09045  FNG24-113922           2002.73             0.0
# ...              ...           ...               ...             ...
# 127805  FN2506-03455    FNG20-4122               NaN             NaN
# 127806  FN2506-03627  FNG23-108194               NaN             NaN
# 127807  FN2506-03625  FNG22-061307               NaN             NaN
# 127808  FN2506-03626  FNG25-136942               NaN             NaN
# 127809  FQ2505-05209          <NA>               NaN             NaN
#
#         prb_commission  after_tax_commission  paid_commission  \
# 0              2067.14               1400.32          1290.30
# 1              6283.89                819.64           738.66
# 2              1439.97                799.99           814.99
# 3              1654.73               1122.85           862.48
# 4              2611.00               2150.24          2002.73
# ...                ...                   ...              ...
# 127805             NaN                   NaN              NaN
# 127806             NaN                   NaN              NaN
# 127807             NaN                   NaN              NaN
# 127808             NaN                   NaN              NaN
# 127809             NaN                   NaN              NaN
#
#         commission_addon  com_invite    com_rank condi_com_status condi_com  \
# 0                    0.0       0.000   33.341025    หารเท่าทุกงวด    หักคอม
# 1                    0.0     273.210    0.000000    หารเท่าทุกงวด    หักคอม
# 2                    0.0     159.997    0.000000  งวดแรกจ่าย 4000    หักคอม
# 3                    0.0     118.195    0.000000    หารเท่าทุกงวด    หักคอม
# 4                    0.0       0.000  122.870000    หารเท่าทุกงวด    หักคอม
# ...                  ...         ...         ...              ...       ...
# 127805               NaN         NaN         NaN             None    หักคอม
# 127806               NaN         NaN         NaN             None    หักคอม
# 127807               NaN         NaN         NaN             None    หักคอม
# 127808               NaN         NaN         NaN             None    หักคอม
# 127809               NaN         NaN         NaN             None    หักคอม
#
#         commission
# 0          1400.32
# 1           819.64
# 2           799.99
# 3          1122.85
# 4          2150.24
# ...            ...
# 127805         NaN
# 127806         NaN
# 127807         NaN
# 127808         NaN
# 127809         NaN
#
# [127810 rows x 13 columns]

# %%
df['car_no'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\jakkapad.wan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'car_no'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df['car_no'].unique()
#
# File c:\Users\jakkapad.wan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File c:\Users\jakkapad.wan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'car_no'

# %%
df = df.replace(r'^\s*$', pd.NA, regex=True)  
df = df[df.count(axis=1) > 1]
df
# Out:
#        quotation_num        id_cus no_car current_campaign  numpay  \
# 0       FQ2505-02001   FNG21-19117    110             None     NaN
# 1       FN2505-00101  FNG23-105321   None             None     NaN
# 2       FQ2505-02002   FNG21-39576    320             <NA>     NaN
# 3       FV2505-02001   FNG21-34561   None             None     NaN
# 4       FQ2505-02003   FNG21-26630    110             None     NaN
# ...              ...           ...    ...              ...     ...
# 166799  FQ2506-26312    FNG20-8942   110E             <NA>     NaN
# 166800  FQ2506-26313  FNG25-135365    110             None     NaN
# 166801  FQ2506-26314   FNG21-16203    610             None     NaN
# 166802  FQ2506-26315  FNG23-083242    110             None     NaN
# 166803  FN2506-03630  FNG23-102679   None             None     NaN
#
#        order_number total_commission ins_commission  prb_commission  \
# 0               NaN              NaN            NaN             NaN
# 1               NaN              NaN            NaN             NaN
# 2               NaN          2219.82              0         2378.76
# 3               NaN             None           None             NaN
# 4               NaN              NaN            NaN             NaN
# ...             ...              ...            ...             ...
# 166799          NaN             <NA>              0         1341.34
# 166800          NaN              NaN            NaN             NaN
# 166801          NaN              NaN            NaN             NaN
# 166802          NaN              NaN            NaN             NaN
# 166803          NaN              NaN            NaN             NaN
#
#         after_tax_commission  ... percent_install chanel_main com_invite  \
# 0                        NaN  ...             NaN         NaN        NaN
# 1                        NaN  ...             NaN         NaN        NaN
# 2                        0.0  ...            None     โอนเงิน        NaN
# 3                        NaN  ...            None        None        NaN
# 4                        NaN  ...             NaN         NaN        NaN
# ...                      ...  ...             ...         ...        ...
# 166799                   NaN  ...               8    ผ่อนชำระ        NaN
# 166800                   NaN  ...             NaN         NaN        NaN
# 166801                   NaN  ...             NaN         NaN        NaN
# 166802                   NaN  ...             NaN         NaN        NaN
# 166803                   NaN  ...             NaN         NaN        NaN
#
#        com_rank money_one money_ten status_vip  condi_com_status  condi_com  \
# 0           NaN       NaN       NaN         no              None     หักคอม
# 1           NaN       NaN       NaN         no              None     หักคอม
# 2           NaN       NaN       NaN         no              None       ปกติ
# 3           NaN       NaN       NaN    yes-old              None     หักคอม
# 4           NaN       NaN       NaN         no              None     หักคอม
# ...         ...       ...       ...        ...               ...        ...
# 166799      NaN       NaN       NaN         no     หารเท่าทุกงวด     หักคอม
# 166800      NaN       NaN       NaN         no              None     หักคอม
# 166801      NaN       NaN       NaN         no              None     หักคอม
# 166802      NaN       NaN       NaN         no              None     หักคอม
# 166803      NaN       NaN       NaN         no              None     หักคอม
#
#        commission
# 0             NaN
# 1             NaN
# 2         2378.76
# 3             NaN
# 4             NaN
# ...           ...
# 166799    1341.34
# 166800        NaN
# 166801        NaN
# 166802        NaN
# 166803        NaN
#
# [166804 rows x 23 columns]

# %%
import pandas as pd
import numpy as np

# แปลงช่องว่างทุกแบบเป็น NaN ชั่วคราว เพื่อการนับข้อมูล
df_temp = df.replace(r'^\s*$', np.nan, regex=True)

# เพิ่มคอลัมน์ช่วยนับจำนวนข้อมูล (non-null)
df['non_empty_count'] = df_temp.notnull().sum(axis=1)

# >>>> ส่วนที่แก้ไขตรงนี้ <<<<
# ตรวจสอบ agent_id ที่ไม่ว่าง (ไม่ใช่ NaN และไม่ใช่ช่องว่าง)
valid_agent_id_mask = df['quotation_num'].astype(str).str.strip().ne('') & df['quotation_num'].notna()

# แยกกลุ่มที่ agent_id ไม่ว่างและ agent_id ว่าง
df_with_id = df[valid_agent_id_mask]
df_without_id = df[~valid_agent_id_mask]

# คัดแถวที่ agent_id ซ้ำ โดยเก็บแถวที่มีข้อมูลมากที่สุด
df_with_id_cleaned = df_with_id.sort_values('non_empty_count', ascending=False).drop_duplicates(subset='quotation_num', keep='first')

# รวมกลับ
df_cleaned = pd.concat([df_with_id_cleaned, df_without_id], ignore_index=True)

# ลบคอลัมน์ช่วย
df_cleaned = df_cleaned.drop(columns=['non_empty_count'])
df_cleaned = df_cleaned.replace(
    to_replace=r'^\s*$|(?i:^none$)|^-$',  # << แก้ตรงนี้
    value=np.nan,
    regex=True
)


df_cleaned.columns = df_cleaned.columns.str.lower()
df_cleaned
# Out:
#        quotation_num        id_cus no_car current_campaign  numpay  \
# 0       FQ2506-04350  FNG23-107003    320        ชวนเพื่อน    10.0
# 1       FQ2505-04940  FNG23-104859  320.1        ชวนเพื่อน    10.0
# 2       FQ2505-24128   FNG21-24169    730        ชวนเพื่อน     4.0
# 3       FQ2505-14310  FNG22-064792    110        ชวนเพื่อน     6.0
# 4       FQ2505-09045  FNG24-113922    110             None     3.0
# ...              ...           ...    ...              ...     ...
# 127805  FN2506-03455    FNG20-4122   None             None     NaN
# 127806  FN2506-03627  FNG23-108194   None             None     NaN
# 127807  FN2506-03625  FNG22-061307   None             None     NaN
# 127808  FN2506-03626  FNG25-136942   None             None     NaN
# 127809  FQ2505-05209          <NA>   <NA>             None     NaN
#
#          order_number total_commission ins_commission  prb_commission  \
# 0       FIN2506-01078          1290.30           0.00         2067.14
# 1       FIN2505-01008           738.66              0         6283.89
# 2       FIN2505-07244           814.99           0.00         1439.97
# 3       FIN2505-04290          1026.71           0.00         1654.73
# 4       FIN2506-00635          2002.73              0         2611.00
# ...               ...              ...            ...             ...
# 127805            NaN              NaN            NaN             NaN
# 127806            NaN              NaN            NaN             NaN
# 127807            NaN              NaN            NaN             NaN
# 127808            NaN              NaN            NaN             NaN
# 127809            NaN              NaN            NaN             NaN
#
#         after_tax_commission  ... percent_install chanel_main com_invite  \
# 0                    1400.32  ...               5     ผ่อนโอน          0
# 1                     819.64  ...              10     ผ่อนโอน     273.21
# 2                     799.99  ...               4    ผ่อนชำระ    159.997
# 3                    1122.85  ...               3    ผ่อนบัตร    118.195
# 4                    2150.24  ...               3     ผ่อนโอน          0
# ...                      ...  ...             ...         ...        ...
# 127805                   NaN  ...             NaN         NaN        NaN
# 127806                   NaN  ...             NaN         NaN        NaN
# 127807                   NaN  ...             NaN         NaN        NaN
# 127808                   NaN  ...             NaN         NaN        NaN
# 127809                   NaN  ...             NaN         NaN        NaN
#
#          com_rank money_one money_ten status_vip  condi_com_status  condi_com  \
# 0       33.341025    1433.0    1432.7    yes-old     หารเท่าทุกงวด     หักคอม
# 1               0    5871.0    5871.0         no     หารเท่าทุกงวด     หักคอม
# 2               0    4000.0       0.0         no   งวดแรกจ่าย 4000     หักคอม
# 3               0    3383.7       0.0    yes-new     หารเท่าทุกงวด     หักคอม
# 4          122.87    5500.0       0.0    yes-old     หารเท่าทุกงวด     หักคอม
# ...           ...       ...       ...        ...               ...        ...
# 127805        NaN       NaN       NaN         no              None     หักคอม
# 127806        NaN       NaN       NaN         no              None     หักคอม
# 127807        NaN       NaN       NaN         no              None     หักคอม
# 127808        NaN       NaN       NaN         no              None     หักคอม
# 127809        NaN       NaN       NaN        NaN              None     หักคอม
#
#        commission
# 0         1400.32
# 1          819.64
# 2          799.99
# 3         1122.85
# 4         2150.24
# ...           ...
# 127805        NaN
# 127806        NaN
# 127807        NaN
# 127808        NaN
# 127809        NaN
#
# [127810 rows x 23 columns]

# %%
df_cleaned.replace(np.nan, "NaN").isin(["none", "-", "None"]).sum()
df_cleaned
# Out:
#        quotation_num        id_cus no_car current_campaign  numpay  \
# 0       FQ2506-04350  FNG23-107003    320        ชวนเพื่อน    10.0
# 1       FQ2505-04940  FNG23-104859  320.1        ชวนเพื่อน    10.0
# 2       FQ2505-24128   FNG21-24169    730        ชวนเพื่อน     4.0
# 3       FQ2505-14310  FNG22-064792    110        ชวนเพื่อน     6.0
# 4       FQ2505-09045  FNG24-113922    110             None     3.0
# ...              ...           ...    ...              ...     ...
# 127805  FN2506-03455    FNG20-4122   None             None     NaN
# 127806  FN2506-03627  FNG23-108194   None             None     NaN
# 127807  FN2506-03625  FNG22-061307   None             None     NaN
# 127808  FN2506-03626  FNG25-136942   None             None     NaN
# 127809  FQ2505-05209          <NA>   <NA>             None     NaN
#
#          order_number total_commission ins_commission  prb_commission  \
# 0       FIN2506-01078          1290.30           0.00         2067.14
# 1       FIN2505-01008           738.66              0         6283.89
# 2       FIN2505-07244           814.99           0.00         1439.97
# 3       FIN2505-04290          1026.71           0.00         1654.73
# 4       FIN2506-00635          2002.73              0         2611.00
# ...               ...              ...            ...             ...
# 127805            NaN              NaN            NaN             NaN
# 127806            NaN              NaN            NaN             NaN
# 127807            NaN              NaN            NaN             NaN
# 127808            NaN              NaN            NaN             NaN
# 127809            NaN              NaN            NaN             NaN
#
#         after_tax_commission  ... percent_install chanel_main com_invite  \
# 0                    1400.32  ...               5     ผ่อนโอน          0
# 1                     819.64  ...              10     ผ่อนโอน     273.21
# 2                     799.99  ...               4    ผ่อนชำระ    159.997
# 3                    1122.85  ...               3    ผ่อนบัตร    118.195
# 4                    2150.24  ...               3     ผ่อนโอน          0
# ...                      ...  ...             ...         ...        ...
# 127805                   NaN  ...             NaN         NaN        NaN
# 127806                   NaN  ...             NaN         NaN        NaN
# 127807                   NaN  ...             NaN         NaN        NaN
# 127808                   NaN  ...             NaN         NaN        NaN
# 127809                   NaN  ...             NaN         NaN        NaN
#
#          com_rank money_one money_ten status_vip  condi_com_status  condi_com  \
# 0       33.341025    1433.0    1432.7    yes-old     หารเท่าทุกงวด     หักคอม
# 1               0    5871.0    5871.0         no     หารเท่าทุกงวด     หักคอม
# 2               0    4000.0       0.0         no   งวดแรกจ่าย 4000     หักคอม
# 3               0    3383.7       0.0    yes-new     หารเท่าทุกงวด     หักคอม
# 4          122.87    5500.0       0.0    yes-old     หารเท่าทุกงวด     หักคอม
# ...           ...       ...       ...        ...               ...        ...
# 127805        NaN       NaN       NaN         no              None     หักคอม
# 127806        NaN       NaN       NaN         no              None     หักคอม
# 127807        NaN       NaN       NaN         no              None     หักคอม
# 127808        NaN       NaN       NaN         no              None     หักคอม
# 127809        NaN       NaN       NaN        NaN              None     หักคอม
#
#        commission
# 0         1400.32
# 1          819.64
# 2          799.99
# 3         1122.85
# 4         2150.24
# ...           ...
# 127805        NaN
# 127806        NaN
# 127807        NaN
# 127808        NaN
# 127809        NaN
#
# [127810 rows x 23 columns]

# %%
# df_cleaned.to_csv('dim_car1.csv', index=False, encoding='utf-8-sig')

# %%
print(df_cleaned.columns)
# Out:
# Index(['quotation_num', 'agent_id', 'no_car', 'current_campaign', 'numpay',
#        'order_number', 'total_commission', 'ins_commission', 'prb_commission',
#        'after_tax_commission', 'paid_commission', 'commission_addon',
#        'condition_install', 'percent_install', 'chanel_main', 'com_invite',
#        'com_rank', 'money_one', 'money_ten', 'status_vip', 'condi_com_status',
#        'condi_com', 'commission'],
#       dtype='object')

# %%
df_cleaned = df_cleaned.replace(r'^\.$', np.nan, regex=True)
df_cleaned
# Out:
#        quotation_num        id_cus no_car current_campaign  numpay  \
# 0       FQ2506-04350  FNG23-107003    320        ชวนเพื่อน    10.0
# 1       FQ2505-04940  FNG23-104859  320.1        ชวนเพื่อน    10.0
# 2       FQ2505-24128   FNG21-24169    730        ชวนเพื่อน     4.0
# 3       FQ2505-14310  FNG22-064792    110        ชวนเพื่อน     6.0
# 4       FQ2505-09045  FNG24-113922    110             None     3.0
# ...              ...           ...    ...              ...     ...
# 127805  FN2506-03455    FNG20-4122   None             None     NaN
# 127806  FN2506-03627  FNG23-108194   None             None     NaN
# 127807  FN2506-03625  FNG22-061307   None             None     NaN
# 127808  FN2506-03626  FNG25-136942   None             None     NaN
# 127809  FQ2505-05209          <NA>   <NA>             None     NaN
#
#          order_number total_commission ins_commission  prb_commission  \
# 0       FIN2506-01078          1290.30           0.00         2067.14
# 1       FIN2505-01008           738.66              0         6283.89
# 2       FIN2505-07244           814.99           0.00         1439.97
# 3       FIN2505-04290          1026.71           0.00         1654.73
# 4       FIN2506-00635          2002.73              0         2611.00
# ...               ...              ...            ...             ...
# 127805            NaN              NaN            NaN             NaN
# 127806            NaN              NaN            NaN             NaN
# 127807            NaN              NaN            NaN             NaN
# 127808            NaN              NaN            NaN             NaN
# 127809            NaN              NaN            NaN             NaN
#
#         after_tax_commission  ... percent_install chanel_main com_invite  \
# 0                    1400.32  ...               5     ผ่อนโอน          0
# 1                     819.64  ...              10     ผ่อนโอน     273.21
# 2                     799.99  ...               4    ผ่อนชำระ    159.997
# 3                    1122.85  ...               3    ผ่อนบัตร    118.195
# 4                    2150.24  ...               3     ผ่อนโอน          0
# ...                      ...  ...             ...         ...        ...
# 127805                   NaN  ...             NaN         NaN        NaN
# 127806                   NaN  ...             NaN         NaN        NaN
# 127807                   NaN  ...             NaN         NaN        NaN
# 127808                   NaN  ...             NaN         NaN        NaN
# 127809                   NaN  ...             NaN         NaN        NaN
#
#          com_rank money_one money_ten status_vip  condi_com_status  condi_com  \
# 0       33.341025    1433.0    1432.7    yes-old     หารเท่าทุกงวด     หักคอม
# 1               0    5871.0    5871.0         no     หารเท่าทุกงวด     หักคอม
# 2               0    4000.0       0.0         no   งวดแรกจ่าย 4000     หักคอม
# 3               0    3383.7       0.0    yes-new     หารเท่าทุกงวด     หักคอม
# 4          122.87    5500.0       0.0    yes-old     หารเท่าทุกงวด     หักคอม
# ...           ...       ...       ...        ...               ...        ...
# 127805        NaN       NaN       NaN         no              None     หักคอม
# 127806        NaN       NaN       NaN         no              None     หักคอม
# 127807        NaN       NaN       NaN         no              None     หักคอม
# 127808        NaN       NaN       NaN         no              None     หักคอม
# 127809        NaN       NaN       NaN        NaN              None     หักคอม
#
#        commission
# 0         1400.32
# 1          819.64
# 2          799.99
# 3         1122.85
# 4         2150.24
# ...           ...
# 127805        NaN
# 127806        NaN
# 127807        NaN
# 127808        NaN
# 127809        NaN
#
# [127810 rows x 23 columns]

# %%
# รายชื่อคอลัมน์ที่เป็น numeric
numeric_columns = [
    'total_commission', 'ins_commission', 'prb_commission',
    'after_tax_commission', 'paid_commission', 'commission_addon',
    'commission', 'com_invite','com_rank'
]

# ลบ , และแปลงเป็น float
for col in numeric_columns:
    df_cleaned[col] = df_cleaned[col].astype(str).str.replace(',', '', regex=False)
    df_cleaned[col] = pd.to_numeric(df_cleaned[col], errors='coerce')

# %%
df_cleaned = df_cleaned.rename(columns={'id_cus': 'agent_id'})

# %%
if 'car_no' in df_cleaned.columns:
    df_cleaned = df_cleaned.drop(columns=['car_no'])

# %%
import pandas as pd
import os
from sqlalchemy import create_engine
from dotenv import load_dotenv

load_dotenv()

host = os.getenv('DB_HOST_test')
user = os.getenv('DB_USER_test')
password = os.getenv('DB_PASSWORD_test')
port = os.getenv('DB_PORT_test')
database = 'fininsurance'  

engine = create_engine(f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}')
rows_inserted = df_cleaned.to_sql('fact_commission', engine, if_exists='append', index=False)
